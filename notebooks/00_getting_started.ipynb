# %% [markdown]
# # Getting Started
#
# Welcome to the course.
#
# You do not need to install Python or any packages on your computer.
# This notebook will set up the course environment automatically in Google Colab.
#
# ### Setup
#
# Run the cell below once when you start a new Colab runtime.
#
# The setup will:
#
# 1. Download the course repository.
# 2. Install the required version of `uv`.
# 3. Recreate the Python environment from the course's locked dependencies.
# 4. Create the course data directories.
# 5. Check that everything is working.
#
# This may take a few minutes the first time.

# %%
# Set up the course environment.
#
# You only need to run this once per Colab runtime.

# !wget -q https://raw.githubusercontent.com/kaancet/2026KU-invivo/main/setup_colab.py
# !python setup_colab.py

# %%
# Mount Google Drive to access the course data (~5-10 GB).
#
# Before running: open the shared data folder link, then
# "Organise > Add shortcut to Drive" so it appears in your My Drive.
#
# A pop-up will ask you to authorise access to your Google Drive.

from google.colab import drive
drive.mount("/content/drive")

from pathlib import Path
DATA_ROOT = Path("/content/drive/MyDrive/2026KU-invivo-data")
assert (DATA_ROOT / "processed").exists(), (
    f"Data not found at {DATA_ROOT}. "
    "Add a shortcut to the shared '2026KU-invivo-data' folder in your Drive, "
    "then re-run this cell."
)
print("Data found:", DATA_ROOT)
